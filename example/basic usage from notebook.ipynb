# %%
# %pip install pipenv

# %%
# %sh

cd ..
# Generar requirements.txt (solo producción)
pipenv requirements > requirements.txt
cat requirements.txt

# %%
# Opción 1: Instalar desde requirements.txt en el directorio actual
# %pip install -r ../requirements.txt

# %%
dbutils.library.restartPython()

# %%
# %sh
cd ..
ls -alt
python setup.py bdist_wheel

# %%
# %pip install ../dist/custom_ai_gateway_policies-0.1.0-py3-none-any.whl

# %%
dbutils.library.restartPython()

# %%
import custom_ai_gateway_policies
